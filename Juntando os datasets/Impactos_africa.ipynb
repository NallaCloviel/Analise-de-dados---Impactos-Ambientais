# %% [markdown]
# # Projeto Final {RE}PROGRAMA - Python: fundamentos e analise de dados
# ### Aluna: Nargylla Fernanda Cloviel Lima

# %% [markdown]
# #### Fazendo a junção de três datasets que possuem colunas em comum para exportar e melhorar a analise.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Dataset sobre água potável

# %%
df_agua = pd.read_csv("C:\\Users\\nargy\\Desktop\\Projeto final\\ECOLENS\\Dados_limpos\\Agua_potável.csv")

# %%
df_agua
# Out:
#      Unnamed: 0                 Country Name Country Code  \
# 0             0                        Aruba          ABW
# 1             1  Africa Eastern and Southern          AFE
# 2             2                  Afghanistan          AFG
# 3             3   Africa Western and Central          AFW
# 4             4                       Angola          AGO
# ..          ...                          ...          ...
# 261         261                       Kosovo          XKX
# 262         262                  Yemen, Rep.          YEM
# 263         263                 South Africa          ZAF
# 264         264                       Zambia          ZMB
# 265         265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  \
# 0    Annual freshwater withdrawals, domestic (% of ...  ER.H2O.FWDM.ZS
# 1    Annual freshwater withdrawals, domestic (% of ...  ER.H2O.FWDM.ZS
# ...

# %%
df_agua.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      266 non-null    int64
#  1   Country Name    266 non-null    object
#  2   Country Code    266 non-null    object
#  3   Indicator Name  266 non-null    object
#  4   Indicator Code  266 non-null    object
#  5   2016            228 non-null    float64
#  6   2017            228 non-null    float64
#  7   2018            228 non-null    float64
#  8   2019            228 non-null    float64
#  9   2020            228 non-null    float64
#  10  Unnamed: 67     0 non-null      float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 23.0+ KB

# %% [markdown]
# #### - separando os países africanos da região subsariana

# %%
países_existentes = df_agua['Country Name'].unique()
print(países_existentes)
# Out:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
paises_subsarianos = ["Africa Eastern and Southern", "Africa Western and Central", "Sub-Saharan Africa (excluding high income)", "Sub-Saharan Africa", "Angola", "Benin", "Botswana", "Burundi", "Cabo Verde", 
                      "Cameroon", "Central African Republic","Chad", "Comoros", "Democratic Republic of the Congo", "Djibouti", "Equatorial Guinea", "Eritrea","Eswatini", "Ethiopia", "Gabon", "Gambia, The", 
                      "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Mozambique", "Namibia", "Niger", "Nigeria", 
                      "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Tanzania", "Togo", "Uganda", "Zambia", "Zimbabwe"]

df_agua = df_agua[df_agua['Country Name'].str.contains('|'.join(paises_subsarianos))]
df_agua
df_agua = df_agua.reset_index(drop=True)
df_agua
# Out:
# C:\Users\nargy\AppData\Local\Temp\ipykernel_14048\2011128120.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_agua = df_agua[df_agua['Country Name'].str.contains('|'.join(paises_subsarianos))]
#     Unnamed: 0                                Country Name Country Code  \
# 0            1                 Africa Eastern and Southern          AFE
# 1            3                  Africa Western and Central          AFW
# 2            4                                      Angola          AGO
# 3           16                                     Burundi          BDI
# 4           18                                       Benin          BEN
# 5           33                                    Botswana          BWA
# 6           34                    Central African Republic          CAF
# 7           42                                    Cameroon          CMR
# ...

# %% [markdown]
# ##### dataset sobre mulheres na agricultura

# %%
df_agricultura = pd.read_csv("C:\\Users\\nargy\\Desktop\\Projeto final\\ECOLENS\\Dados_limpos\\Mulheres_agricultura.csv")
df_agricultura
# Out:
#      Unnamed: 0                 Country Name Country Code  \
# 0             0                        Aruba          ABW
# 1             1  Africa Eastern and Southern          AFE
# 2             2                  Afghanistan          AFG
# 3             3   Africa Western and Central          AFW
# 4             4                       Angola          AGO
# ..          ...                          ...          ...
# 261         261                       Kosovo          XKX
# 262         262                  Yemen, Rep.          YEM
# 263         263                 South Africa          ZAF
# 264         264                       Zambia          ZMB
# 265         265                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
# 1    Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
# ...

# %%
df_agricultura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      266 non-null    int64
#  1   Country Name    266 non-null    object
#  2   Country Code    266 non-null    object
#  3   Indicator Name  266 non-null    object
#  4   Indicator Code  266 non-null    object
#  5   2016            235 non-null    float64
#  6   2017            235 non-null    float64
#  7   2018            235 non-null    float64
#  8   2019            235 non-null    float64
#  9   2020            235 non-null    float64
#  10  2021            233 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 23.0+ KB

# %% [markdown]
# #### - separando os países africanos da Africa subsariana

# %%
paises_subsarianos = ["Africa Eastern and Southern", "Africa Western and Central", "Sub-Saharan Africa (excluding high income)", "Sub-Saharan Africa", "Angola", "Benin", "Botswana", "Burundi", "Cabo Verde", "Cote d'Ivoire" 
                      "Cameroon", "Central African Republic","Chad", "Comoros", "Democratic Republic of the Congo", "Djibouti", "Equatorial Guinea", "Eritrea","Eswatini", "Ethiopia", "Gabon", "Gambia, The", 
                      "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Mozambique", "Namibia", "Niger", "Nigeria", 
                      "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Tanzania", "Togo", "Uganda", "Zambia", "Zimbabwe"]

df_agricultura = df_agricultura[df_agricultura['Country Name'].str.contains('|'.join(paises_subsarianos))]
df_agricultura
# Out:
# C:\Users\nargy\AppData\Local\Temp\ipykernel_14048\3374128089.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_agricultura = df_agricultura[df_agricultura['Country Name'].str.contains('|'.join(paises_subsarianos))]
#      Unnamed: 0                                Country Name Country Code  \
# 1             1                 Africa Eastern and Southern          AFE
# 3             3                  Africa Western and Central          AFW
# 4             4                                      Angola          AGO
# 16           16                                     Burundi          BDI
# 18           18                                       Benin          BEN
# 33           33                                    Botswana          BWA
# 34           34                    Central African Republic          CAF
# 46           46                                     Comoros          COM
# ...

# %%
df_agricultura = df_agricultura.reset_index(drop=True)
df_agricultura
# Out:
#     Unnamed: 0                                Country Name Country Code  \
# 0            1                 Africa Eastern and Southern          AFE
# 1            3                  Africa Western and Central          AFW
# 2            4                                      Angola          AGO
# 3           16                                     Burundi          BDI
# 4           18                                       Benin          BEN
# 5           33                                    Botswana          BWA
# 6           34                    Central African Republic          CAF
# 7           46                                     Comoros          COM
# 8           47                                  Cabo Verde          CPV
# 9           56                                    Djibouti          DJI
# 10          69                                     Eritrea          ERI
# 11          72                                    Ethiopia          ETH
# ...

# %% [markdown]
# #### Dataset sobre terras aráveis

# %%
df_terras = pd.read_csv("C:\\Users\\nargy\\Desktop\\Projeto final\\ECOLENS\\Dados_limpos\\Terras_agricultura_africa.csv")
df_terras
# Out:
#      Unnamed: 0                 Country Name Country Code  \
# 0             0                        Aruba          ABW
# 1             1  Africa Eastern and Southern          AFE
# 2             2                  Afghanistan          AFG
# 3             3   Africa Western and Central          AFW
# 4             4                       Angola          AGO
# ..          ...                          ...          ...
# 261         261                       Kosovo          XKX
# 262         262                  Yemen, Rep.          YEM
# 263         263                 South Africa          ZAF
# 264         264                       Zambia          ZMB
# 265         265                     Zimbabwe          ZWE
#
#                          Indicator Name  Indicator Code       2016       2017  \
# 0    Agricultural land (% of land area)  AG.LND.AGRI.ZS  11.111111  11.111111
# 1    Agricultural land (% of land area)  AG.LND.AGRI.ZS  46.152439  46.271150
# ...

# %%
df_terras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      266 non-null    int64
#  1   Country Name    266 non-null    object
#  2   Country Code    266 non-null    object
#  3   Indicator Name  266 non-null    object
#  4   Indicator Code  266 non-null    object
#  5   2016            258 non-null    float64
#  6   2017            258 non-null    float64
#  7   2018            258 non-null    float64
#  8   2019            258 non-null    float64
#  9   2020            258 non-null    float64
#  10  2021            258 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 23.0+ KB

# %%
paises_subsarianos = ["Africa Eastern and Southern", "Africa Western and Central", "Sub-Saharan Africa (excluding high income)", "Sub-Saharan Africa", "Angola", "Benin", "Botswana", "Burundi", "Cabo Verde", 
                      "Cameroon", "Central African Republic","Chad", "Comoros", "Democratic Republic of the Congo", "Djibouti", "Equatorial Guinea", "Eritrea","Eswatini", "Ethiopia", "Gabon", "Gambia, The", 
                      "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Mozambique", "Namibia", "Niger", "Nigeria", 
                      "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Tanzania", "Togo", "Uganda", "Zambia", "Zimbabwe"]

df_terras = df_terras[df_terras['Country Name'].str.contains('|'.join(paises_subsarianos))]
df_terras
# Out:
# C:\Users\nargy\AppData\Local\Temp\ipykernel_14048\21257149.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_terras = df_terras[df_terras['Country Name'].str.contains('|'.join(paises_subsarianos))]
#      Unnamed: 0                                Country Name Country Code  \
# 1             1                 Africa Eastern and Southern          AFE
# 3             3                  Africa Western and Central          AFW
# 4             4                                      Angola          AGO
# 16           16                                     Burundi          BDI
# 18           18                                       Benin          BEN
# 33           33                                    Botswana          BWA
# 34           34                    Central African Republic          CAF
# 42           42                                    Cameroon          CMR
# ...

# %%
df_terras = df_terras.reset_index(drop=True)
df_terras
# Out:
#     Unnamed: 0                                Country Name Country Code  \
# 0            1                 Africa Eastern and Southern          AFE
# 1            3                  Africa Western and Central          AFW
# 2            4                                      Angola          AGO
# 3           16                                     Burundi          BDI
# 4           18                                       Benin          BEN
# 5           33                                    Botswana          BWA
# 6           34                    Central African Republic          CAF
# 7           42                                    Cameroon          CMR
# 8           46                                     Comoros          COM
# 9           47                                  Cabo Verde          CPV
# 10          56                                    Djibouti          DJI
# 11          69                                     Eritrea          ERI
# ...

# %% [markdown]
# ### Fazendo a junção dos três datasets com base no Country name

# %%
df_uniao = pd.merge(df_agua, df_terras, on='Country Name')
df_uniao
# Out:
#     Unnamed: 0_x                                Country Name Country Code_x  \
# 0              1                 Africa Eastern and Southern            AFE
# 1              3                  Africa Western and Central            AFW
# 2              4                                      Angola            AGO
# 3             16                                     Burundi            BDI
# 4             18                                       Benin            BEN
# 5             33                                    Botswana            BWA
# 6             34                    Central African Republic            CAF
# 7             42                                    Cameroon            CMR
# 8             46                                     Comoros            COM
# 9             47                                  Cabo Verde            CPV
# 10            56                                    Djibouti            DJI
# ...

# %%
df_uniao_final = pd.merge(df_uniao, df_agricultura, on='Country Name')
df_uniao_final
# Out:
#     Unnamed: 0_x                                Country Name Country Code_x  \
# 0              1                 Africa Eastern and Southern            AFE
# 1              3                  Africa Western and Central            AFW
# 2              4                                      Angola            AGO
# 3             16                                     Burundi            BDI
# 4             18                                       Benin            BEN
# 5             33                                    Botswana            BWA
# 6             34                    Central African Republic            CAF
# 7             46                                     Comoros            COM
# 8             47                                  Cabo Verde            CPV
# 9             56                                    Djibouti            DJI
# 10            69                                     Eritrea            ERI
# ...

# %% [markdown]
# #### Exportando para criar um único dataset

# %%
df_uniao_final.to_csv("Impactos_africa.csv")
